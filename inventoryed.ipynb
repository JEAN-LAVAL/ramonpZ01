# %%
#inventory.py in Ed
import pandas as pd
def get_price(inventory, item):
    # fill me in
    return
def update_price(inventory, item, price):
    frame=pd.DataFrame(inventory)
    frame
    print(frame.veg)
    i=frame.veg[(frame.veg).isin([item])].empty #testing if item is not found in 
                                                # coulumn of frame
    #isin works for only one column of DataFrame at a time
    print (i)
    
    
         
    #else:
    
    if i == True: #new item is to be added to inventory:
        print('Not yet in DataFrame')
        #index=2
        index= 3
        #frame2.veg[0]= item
        #frame2.price[0]= price
        ##must form another data frame to hold new record to append or
        ##concatenate
        frame2=pd.DataFrame({"veg":[item],
                             "price":[price]}) 
        #frame.append(fname.veg[3], fname.price[3])
        print(frame2)
        frame3=frame.append(frame2)
#Syntax: DataFrame.append(other, ignore_index=False, verify_integrity=False, sort=None)        

        print('Appended')
        print(frame3)       
        ###concatenate. Include new data as part of frame dataframe
        ##must form another dataframe to concatenate
        frame4 = pd.concat([frame, frame2], ignore_index=True)
        print('Concatenate')
        print(frame4)
    else:
        print('exists') #if price new then update inventory with new price
        if item=='banana':
            index=0
        elif item=='apple':
            index=1
        elif item=='bread loaf':
            index=2
        
        print(frame.veg, frame.price)
        new_price = price
            
        frame.price[index]=new_price
        print(frame)
        
           
        
    #In [5]: s[s.isin(['z'])].empty
    #Out[5]: True
    #*****************************
    

def display_inventory(inventory):
    # fill me in
    frame=pd.DataFrame(inventory)
    print(frame.veg)
    print(frame)
#######
#dfObj = pd.DataFrame(students, columns = ['Name' , 'Age', 'City'], index=['a', 'b', 'c'])
datadic={'veg':['banana', 'apple', 'bread loaf'],
         'price':[1.25,2,3.25],}
display_inventory(datadic)
###################

reqprice=input('Please enter price: ')
req_item=str(input('Please enter veg to update: '))
update_price(datadic, req_item, reqprice)
####

# Single selections using iloc and DataFrame
# Rows:
#data.iloc[0] # first row of data frame (Aleshia Tomkiewicz) - Note a Series data type output.
#data.iloc[1] # second row of data frame (Evan Zigomalas)
#data.iloc[-1] # last row of data frame (Mi Richan)
# Columns:
#data.iloc[:,0] # first column of data frame (first_name)
#data.iloc[:,1] # second column of data frame (last_name)
#data.iloc[:,-1] # last column of data frame (id)

#Multiple columns and rows can be selected together using the .iloc indexer.

# Multiple row and column selections using iloc and DataFrame
#data.iloc[0:5] # first five rows of dataframe
#data.iloc[:, 0:2] # first two columns of data frame with all rows
#data.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
#data.iloc[0:5, 5:8] # first 5 rows and 5th, 6th, 7th columns of data frame (county -> phone1).
#>>> df = DataFrame({'A': [1, 2, 3], 'B': [1, 4, 7]})
    #>>> df.isin({'A': [1, 3], 'B': [4, 7, 12]})
    #  A      B
#0   #True  False  # Note that B didn't match 1 here.
#1   #False   True
#2   #True   True
    # fill me in
# Out:
# 0        banana
# 1         apple
# 2    bread loaf
# Name: veg, dtype: object
#           veg  price
# 0      banana   1.25
# 1       apple   2.00
# 2  bread loaf   3.25
# Please enter price: 21
# Please enter veg to update: fr
# 0        banana
# 1         apple
# 2    bread loaf
# Name: veg, dtype: object
# True
# Not yet in DataFrame
#   veg price
# 0  fr    21
# Appended
#           veg price
# 0      banana  1.25
# 1       apple     2
# 2  bread loaf  3.25
# 0          fr    21
# Concatenate
#           veg price
# 0      banana  1.25
# 1       apple     2
# 2  bread loaf  3.25
# 3          fr    21
